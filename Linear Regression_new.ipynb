# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
data = pd.read_excel('houseprice.xls')
data
# Out:
#     area  room  floor  age  price
# 0   1000     2      1   10  10942
# 1   1050     1      1    1  11942
# 2   1100     3      1    5  10442
# 3   1150     1      1   10  11442
# 4   1200     2      1   15  12442
# 5   1250     1      1    5  15472
# 6   1300     3      1   20  12572
# 7   1350     3      1   20  13172
# 8   1400     2      2    7  14672
# 9   1450     1      1   15  13472
# 10  1500     3      2    6  13777
# 11  1510     2      1   15  14902
# 12  1540     3      1   20  15902
# 13  1550     1      2   20  16369
# 14  1570     2      2    7  17477
# 15  1600     1      2   20  17665
# 16  1600     3      2    6  18977
# 17  1650     1      2    7  16369
# 18  1650     2      1   12  16560
# 19  1700     2      1   12  17477
# 20  1700     3      1   14  17128
# 21  1750     1      1    6  18960
# 22  1750     4      1   16  19128
# 23  1800     3      1   14  20919
# 24  1800     2      1   29  17919
# 25  1850     1      1   12  17909
# 26  1850     1      2    2  19495
# 27  1900     1      1   14  19123
# 28  1900     4      2    1  20909
# 29  1950     1      1   16  20695
# ..   ...   ...    ...  ...    ...
# 70  3050     2      1   15  31407
# 71  3087     5      3   16  31093
# 72  3100     3      2    6  32789
# 73  3128     4      3   29  32607
# 74  3150     2      1   20  31477
# 75  3169     5      3    2  31789
# 76  3200     2      1   12  32603
# 77  3250     2      2    7  33603
# 78  3300     2      2    6  35972
# 79  3350     2      1   12  33072
# 80  3400     2      1   14  33672
# 81  3450     2      1   16  35172
# 82  3500     3      1   29  33972
# 83  3550     3      1   29  34328
# 84  3600     3      2    2  37005
# 85  3650     3      2    1  38005
# 86  3700     3      1   10  36505
# 87  3750     3      1    5  37505
# 88  3800     3      1   14  38505
# 89  3850     3      1   15  41412
# 90  3900     3      1   20  38512
# 91  3950     3      1   20  39112
# 92  4000     3      2    7  40612
# 93  4050     2      1   16  39412
# 94  3850     3      1   15  41412
# 95  3850     3      1   15  40912
# 96  3900     3      1   20  39412
# 97  3950     3      1   20  39112
# 98  4000     3      2    7  39612
# 99  4050     2      1   16  39912
#
# [100 rows x 5 columns]

# %%
x = np.array(data.area)
y = np.array(data.price)
x.size
# Out:
# 100

# %%
colors = (0,0,0)
s = np.random.rand()
plt.scatter(x, y,s,c=colors,linewidth=1)
plt.title('Scatter plot ')
plt.xlabel('area')
plt.ylabel('price')
plt.figure(figsize=(50,25))
plt.show()

# %%
x = (x - x.mean()) / (x.max()-x.min())

x = np.c_[np.ones(x.size), x]
x
# Out:
# array([[ 1.        , -0.5060918 ],
#        [ 1.        , -0.48969836],
#        [ 1.        , -0.47330492],
#        [ 1.        , -0.45691148],
#        [ 1.        , -0.44051803],
#        [ 1.        , -0.42412459],
#        [ 1.        , -0.40773115],
#        [ 1.        , -0.3913377 ],
#        [ 1.        , -0.37494426],
#        [ 1.        , -0.35855082],
#        [ 1.        , -0.34215738],
#        [ 1.        , -0.33887869],
#        [ 1.        , -0.32904262],
#        [ 1.        , -0.32576393],
#        [ 1.        , -0.31920656],
#        [ 1.        , -0.30937049],
#        [ 1.        , -0.30937049],
#        [ 1.        , -0.29297705],
#        [ 1.        , -0.29297705],
#        [ 1.        , -0.27658361],
#        [ 1.        , -0.27658361],
#        [ 1.        , -0.26019016],
#        [ 1.        , -0.26019016],
#        [ 1.        , -0.24379672],
#        [ 1.        , -0.24379672],
#        [ 1.        , -0.22740328],
#        [ 1.        , -0.22740328],
#        [ 1.        , -0.21100984],
#        [ 1.        , -0.21100984],
#        [ 1.        , -0.19461639],
#        [ 1.        , -0.19461639],
#        [ 1.        , -0.17822295],
#        [ 1.        , -0.17822295],
#        [ 1.        , -0.16182951],
#        [ 1.        , -0.16182951],
#        [ 1.        , -0.14543607],
#        [ 1.        , -0.14543607],
#        [ 1.        , -0.12904262],
#        [ 1.        , -0.1208459 ],
#        [ 1.        , -0.11264918],
#        [ 1.        , -0.09625574],
#        [ 1.        , -0.09625574],
#        [ 1.        , -0.0798623 ],
#        [ 1.        , -0.07166557],
#        [ 1.        , -0.06346885],
#        [ 1.        , -0.04707541],
#        [ 1.        , -0.04707541],
#        [ 1.        , -0.03068197],
#        [ 1.        , -0.02248525],
#        [ 1.        , -0.01428852],
#        [ 1.        ,  0.00210492],
#        [ 1.        ,  0.00210492],
#        [ 1.        ,  0.01849836],
#        [ 1.        ,  0.02669508],
#        [ 1.        ,  0.0348918 ],
#        [ 1.        ,  0.05128525],
#        [ 1.        ,  0.05128525],
#        [ 1.        ,  0.06767869],
#        [ 1.        ,  0.07587541],
#        [ 1.        ,  0.08407213],
#        [ 1.        ,  0.08407213],
#        [ 1.        ,  0.09751475],
#        [ 1.        ,  0.10046557],
#        [ 1.        ,  0.11685902],
#        [ 1.        ,  0.1244    ],
#        [ 1.        ,  0.13325246],
#        [ 1.        ,  0.13784262],
#        [ 1.        ,  0.1496459 ],
#        [ 1.        ,  0.15128525],
#        [ 1.        ,  0.16472787],
#        [ 1.        ,  0.16603934],
#        [ 1.        ,  0.17817049],
#        [ 1.        ,  0.18243279],
#        [ 1.        ,  0.19161311],
#        [ 1.        ,  0.19882623],
#        [ 1.        ,  0.20505574],
#        [ 1.        ,  0.21521967],
#        [ 1.        ,  0.23161311],
#        [ 1.        ,  0.24800656],
#        [ 1.        ,  0.2644    ],
#        [ 1.        ,  0.28079344],
#        [ 1.        ,  0.29718689],
#        [ 1.        ,  0.31358033],
#        [ 1.        ,  0.32997377],
#        [ 1.        ,  0.34636721],
#        [ 1.        ,  0.36276066],
#        [ 1.        ,  0.3791541 ],
#        [ 1.        ,  0.39554754],
#        [ 1.        ,  0.41194098],
#        [ 1.        ,  0.42833443],
#        [ 1.        ,  0.44472787],
#        [ 1.        ,  0.46112131],
#        [ 1.        ,  0.47751475],
#        [ 1.        ,  0.4939082 ],
#        [ 1.        ,  0.42833443],
#        [ 1.        ,  0.42833443],
#        [ 1.        ,  0.44472787],
#        [ 1.        ,  0.46112131],
#        [ 1.        ,  0.47751475],
#        [ 1.        ,  0.4939082 ]])

# %%
alpha = 0.01 #Step size
iterations = 2000 #No. of iterations
m = y.size #No. of data points
##np.random.seed() #Set the seed
theta = np.random.rand(2) #Pick some random values to start with
theta
# Out:
# array([ 0.96868867,  0.18870042])

# %%
#GRADIENT DESCENT
def gradient_descent(x, y, theta, iterations, alpha):
    past_costs = []
    past_thetas = [theta]
    for i in range(iterations):
        prediction = np.dot(x, theta)
        error = prediction - y
        cost = 1/(2*m) * np.dot(error.T, error)
        past_costs.append(cost)
        theta = theta - (alpha * (1/m) * np.dot(x.T, error))
        past_thetas.append(theta)
        
    return past_thetas, past_costs

#Pass the relevant variables to the function and get the new values back...
past_thetas, past_costs = gradient_descent(x, y, theta, iterations, alpha)
theta = past_thetas[-1]

#Print the results...
print("Gradient Descent: {:.2f}, {:.2f}".format(theta[0], theta[1]))
# Out:
# Gradient Descent: 26090.99, 8430.39

# %%
#Plot the cost function...
plt.title('Cost Function J')
plt.xlabel('No. of iterations')
plt.ylabel('Cost')
plt.plot(past_costs)
plt.show()
